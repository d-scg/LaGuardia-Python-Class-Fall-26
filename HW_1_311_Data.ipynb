# %% [markdown]
# Homework #1 using NYC 311 calls dataset.

# %%
import pandas as pd
df = pd.read_csv ('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/refs/heads/master/311_Service_Requests_from_2019May.csv')
# Out:
# /tmp/ipykernel_1652/1842884941.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv ('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/refs/heads/master/311_Service_Requests_from_2019May.csv')

# %% [markdown]
# Q. Number of Columns and rows in the dataset.
# A. 21 Columns, 69637 rows

# %%
df.shape
# Out:
# (69637, 21)

# %% [markdown]
# Q. What are some relevant summary statistics.
# A. The column Agency has 20 individual agencies, the majority of the complaints are NYPD related issues recurring in 21188 calls out of 69637. Agency is a string data type, and the summary is calculated on a categorical variable(The describe() method excludes null values when calculatind the summary stats).

# %%
df["Agency"].describe()
# Out:
# count     69637
# unique       20
# top        NYPD
# freq      21188
# Name: Agency, dtype: object

# %%
#Print the columns'names
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Complaint Type',
#        'Location Type', 'Incident Zip', 'Incident Address', 'Street Name',
#        'Address Type', 'City', 'Landmark', 'Facility Type', 'Status',
#        'Due Date', 'Resolution Description', 'BBL', 'Borough', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
# Visualize firts 25 rows of dataset.
df.head(25)
# Out:
#     Unique Key   Created Date      Closed Date Agency  \
# 0     42680103  5/1/2019 0:00  5/16/2019 21:45    DEP
# 1     42530481  5/1/2019 0:00    5/2/2019 0:00  DOHMH
# 2     42527619  5/1/2019 0:00   5/13/2019 0:00  DOHMH
# 3     42526597  5/1/2019 0:00    5/2/2019 0:00  DOHMH
# 4     42526595  5/1/2019 0:00    5/2/2019 0:00  DOHMH
# 5     42524590  5/1/2019 0:00    5/1/2019 0:00  DOHMH
# 6     42530673  5/1/2019 0:00   5/1/2019 15:22  DOHMH
# 7     42529368  5/1/2019 0:00   5/1/2019 14:22  DOHMH
# 8     42526596  5/1/2019 0:00   5/1/2019 14:53  DOHMH
# 9     42519734  5/1/2019 0:00   5/1/2019 11:23  DOHMH
# 10    42613472  5/1/2019 0:00              NaN    DEP
# 11    42524126  5/1/2019 0:00    5/3/2019 1:45    DEP
# 12    42520595  5/1/2019 0:00    5/1/2019 4:16   NYPD
# 13    42580687  5/1/2019 0:01   5/3/2019 15:41    HPD
# 14    42527913  5/1/2019 0:01   5/1/2019 15:46    HPD
# 15    42513528  5/1/2019 0:01    5/1/2019 1:44   NYPD
# ...

# %%
#Examole of summary statistics for a numerical variable. It includes mean, DSD, min, max , and quartiles.
df["Unique Key"].describe()
# Out:
# count    6.963700e+04
# mean     4.260307e+07
# std      5.269818e+04
# min      4.251278e+07
# 25%      4.258004e+07
# 50%      4.260019e+07
# 75%      4.262095e+07
# max      4.297343e+07
# Name: Unique Key, dtype: float64

# %%
#How many null values each column contains?
df.isnull().sum()
# Out:
# Unique Key                    0
# Created Date                  0
# Closed Date                5011
# Agency                        0
# Complaint Type                0
# Location Type             15659
# Incident Zip               2248
# Incident Address          10604
# Street Name               10605
# Address Type               1330
# City                       2221
# Landmark                  69621
# Facility Type             45556
# Status                        0
# Due Date                  36798
# Resolution Description     6058
# BBL                       13935
# Borough                       0
# Latitude                   4003
# Longitude                  4003
# Location                   4003
# dtype: int64

# %%
#What is the data type of each variable and how many non-null values each has.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69637 entries, 0 to 69636
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unique Key              69637 non-null  int64
#  1   Created Date            69637 non-null  object
#  2   Closed Date             64626 non-null  object
#  3   Agency                  69637 non-null  object
#  4   Complaint Type          69637 non-null  object
#  5   Location Type           53978 non-null  object
#  6   Incident Zip            67389 non-null  object
#  7   Incident Address        59033 non-null  object
#  8   Street Name             59032 non-null  object
#  9   Address Type            68307 non-null  object
#  10  City                    67416 non-null  object
#  11  Landmark                16 non-null     object
#  12  Facility Type           24081 non-null  object
#  13  Status                  69637 non-null  object
# ...

# %% [markdown]
# Q. Create 2-3 visualizations from this dataset.
# A. Bar chart of 311 complaints by status and bar chart of top 5 311 complaint types.

# %%
df.groupby(["Status"]) ["Unique Key"].count().sort_values(ascending=False).plot(kind= "bar", ylabel= "Count of Compaints", title= "Count of Complaints by Status")
# Out:
# <Axes: title={'center': 'Count of Complaints by Status'}, xlabel='Status', ylabel='Count of Compaints'>

# %%
df["Complaint Type"].value_counts().head(5).plot(kind= "bar", ylabel= "Count of Complaints", title= "Top 5 Complaint Types", color="orange")
# Out:
# <Axes: title={'center': 'Top 5 Complaint Types'}, xlabel='Complaint Type', ylabel='Count of Complaints'>

# %% [markdown]
# Q. what borough has the most complaints.
# A. Brooklyn with 22247 complaints.

# %%
df.groupby(['Borough']) ['Unique Key'].count(). sort_values(ascending=False)
# Out:
# Borough
# BROOKLYN         22247
# QUEENS           18623
# MANHATTAN        13133
# BRONX            10925
# STATEN ISLAND     3848
# Unspecified        861
# Name: Unique Key, dtype: int64

# %% [markdown]
# Q. Create a plot of counts by borough for noise complaints.
# A. The bar chart shows that the majority of noise complaints are made in Manhattan (more than double that in Queens).

# %%
#Plot of counts
df[df["Complaint Type"] =='Noise'].groupby(['Borough']) ['Unique Key'].count(). sort_values(ascending=False).plot(kind='bar',ylabel= 'Count of Complaints', title = "Count of Noise Complaints by Borough", color = "green")
# Out:
# <Axes: title={'center': 'Count of Noise Complaints by Borough'}, xlabel='Borough', ylabel='Count of Complaints'>

# %% [markdown]
# Q. Find one more interesting piece of information.
# A. I wanted to investigate the break down of an information in the previous graph, representing the 311 complaints by status. In that bar chart, the Status categories 'Started' and 'Email Sent' were not visualized as having any cases because of the measurement unit. In that graph each unit is one thousand. The 'Started' (117) and 'Email Sent' (40) Status categories have less than a thousand cases, thus the graph doesn't pick them up. Here I wanted to break that information up and see how many cases are specifically in these two categories, and then plot them with a separate graph.

# %%
df[df["Status"].isin(['Started', 'Email Sent'])].groupby(['Status']) ['Unique Key'].count(). sort_values(ascending=False)
# Out:
# Status
# Started       117
# Email Sent     40
# Name: Unique Key, dtype: int64

# %%
df[df["Status"].isin(['Started', 'Email Sent'])].groupby(['Status']) ['Unique Key'].count(). sort_values(ascending=False).plot(kind= 'bar',
ylabel= 'Count of Selected Status', title= 'Complaints by Selected Status')
# Out:
# <Axes: title={'center': 'Complaints by Selected Status'}, xlabel='Status', ylabel='Count of Selected Status'>
